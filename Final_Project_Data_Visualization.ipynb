# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Main Data

# %%
data = pd.read_csv("https://raw.githubusercontent.com/21accel/bank_churn_prediction/main/BankChurners.csv")

# %%
data.drop(columns=['CLIENTNUM'], axis=1, inplace=True)
data
# Out:
#           Attrition_Flag  ...  Avg_Utilization_Ratio
# 0      Existing Customer  ...                  0.061
# 1      Existing Customer  ...                  0.105
# 2      Existing Customer  ...                  0.000
# 3      Existing Customer  ...                  0.760
# 4      Existing Customer  ...                  0.000
# ...                  ...  ...                    ...
# 10122  Existing Customer  ...                  0.462
# 10123  Attrited Customer  ...                  0.511
# 10124  Attrited Customer  ...                  0.000
# 10125  Attrited Customer  ...                  0.000
# 10126  Attrited Customer  ...                  0.189
#
# [10127 rows x 20 columns]

# %% [markdown]
# ##Attrition Flag

# %%
data.value_counts('Attrition_Flag')
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# dtype: int64

# %%
# get count existing user and attrited user
existing = data.query("Attrition_Flag == 'Existing Customer'")
existing = existing['Gender'].count()
attrited = data.query("Attrition_Flag == 'Attrited Customer'")
attrited = attrited['Gender'].count()
attrition_Flag = pd.DataFrame(data=[existing,attrited], index=['Existing Customer','Attrited Customer'],columns=['Counts'])
attrition_Flag_T = attrition_Flag.T
attrition_Flag_T
# Out:
#         Existing Customer  Attrited Customer
# Counts               8500               1627

# %%
label = ['Existing Customer','Attrited Customer']
counts = [existing, attrited]
# bar chart for Attrition_Flag
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Attrited Flag")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.1f%%", pctdistance=1.1, labeldistance=1.25)
plt.legend(labels=label)
plt.title("Attrited Flag", fontsize=20);
pie.show()

# %% [markdown]
# ##Customer Age

# %%
data.value_counts('Customer_Age')
# Out:
# Customer_Age
# 44    500
# 49    495
# 46    490
# 45    486
# 47    479
# 43    473
# 48    472
# 50    452
# 42    426
# 51    398
# 53    387
# 41    379
# 52    376
# 40    361
# 39    333
# 54    307
# 38    303
# 55    279
# 56    262
# 37    260
# 57    223
# 36    221
# 35    184
# 58    157
# 59    157
# 34    146
# 60    127
# 33    127
# 32    106
# 65    101
# 62     93
# 61     93
# 31     91
# 26     78
# 30     70
# 63     65
# 29     56
# 64     43
# 27     32
# 28     29
# 67      4
# 66      2
# 68      2
# 70      1
# 73      1
# dtype: int64

# %%
age_20s = data.query("Customer_Age >= 20 & Customer_Age < 30")
age_20s = age_20s['Gender'].count()
age_30s = data.query("Customer_Age >= 30 & Customer_Age < 40")
age_30s = age_30s['Gender'].count()
age_40s = data.query("Customer_Age >= 40 & Customer_Age < 50")
age_40s = age_40s['Gender'].count()
age_50s = data.query("Customer_Age >= 50 & Customer_Age < 60")
age_50s = age_50s['Gender'].count()
age_60s = data.query("Customer_Age >= 60 & Customer_Age < 70")
age_60s = age_60s['Gender'].count()
age_70s = data.query("Customer_Age >= 70")
age_70s = age_70s['Gender'].count()
ages = pd.DataFrame(data=[age_20s,age_30s,age_40s,age_50s,age_60s,age_70s], index=['20-29','30-39','40-49','50-59','60-69','70~'],columns=['Counts'])
ages_T = ages.T
ages_T
# Out:
#         20-29  30-39  40-49  50-59  60-69  70~
# Counts    195   1841   4561   2998    530    2

# %%
label = ['20-29','30-39','40-49','50-59','60-69','70~']
counts = [age_20s,age_30s,age_40s,age_50s,age_60s,age_70s]
plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Customer Age")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.3f%%", pctdistance=1.1, labeldistance=1.25)
plt.legend(labels=label)
plt.title("Customer Age", fontsize=20);
pie.show()

# %% [markdown]
# ##Gender

# %%
data.value_counts('Gender')
# Out:
# Gender
# F    5358
# M    4769
# dtype: int64

# %%
# get count each gender
male = data.query("Gender == 'M'")
male = male['Gender'].count()
female = data.query("Gender == 'F'")
female = female['Gender'].count()
gender = pd.DataFrame(data=[male,female], index=['Male','Female'],columns=['Counts'])
gender_T = gender.T
gender_T
# Out:
#         Male  Female
# Counts  4769    5358

# %%
label = ['Male','Female']
counts = [male, female]
plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)

# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Gender Count")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.3f%%", pctdistance=1.1, labeldistance=1.25,startangle=90)
plt.legend(labels=label)
plt.title("Gender", fontsize=20);
pie.show()

# %% [markdown]
# ##Dependent_count

# %%
data.value_counts('Dependent_count')
# Out:
# Dependent_count
# 3    2732
# 2    2655
# 1    1838
# 4    1574
# 0     904
# 5     424
# dtype: int64

# %%
# get count each dependent number
dep_0 = data.query("Dependent_count == 0")
dep_0 = dep_0['Gender'].count()
dep_1 = data.query("Dependent_count == 1")
dep_1 = dep_1['Gender'].count()
dep_2 = data.query("Dependent_count == 2")
dep_2 = dep_2['Gender'].count()
dep_3 = data.query("Dependent_count == 3")
dep_3 = dep_3['Gender'].count()
dep_4 = data.query("Dependent_count == 4")
dep_4 = dep_4['Gender'].count()
dep_5 = data.query("Dependent_count >= 5")
dep_5 = dep_5['Gender'].count()
dependent = pd.DataFrame(data=[dep_0,dep_1,dep_2,dep_3,dep_4,dep_5], index=['0','1','2','3','4','5~'],columns=['Counts'])
dependent_T = dependent.T
dependent_T
# Out:
#           0     1     2     3     4   5~
# Counts  904  1838  2655  2732  1574  424

# %%
label = ['0','1','2','3','4','5~']
counts = [dep_0,dep_1,dep_2,dep_3,dep_4,dep_5]
plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Dependent Count")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.2f%%", pctdistance=1.1, labeldistance=1.25, startangle=0)
plt.legend(labels=label)
plt.title("Dependent Count", fontsize=20);
pie.show()

# %% [markdown]
# ##Education_Level

# %%
data.value_counts('Education_Level')
# Out:
# Education_Level
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# dtype: int64

# %%
high_school = data.query('Education_Level == "High School"')
high_school = high_school['Gender'].count()
graduate = data.query('Education_Level == "Graduate"')
graduate = graduate['Gender'].count()
uneducated = data.query('Education_Level == "Uneducated"')
uneducated = uneducated['Gender'].count()
unknown = data.query('Education_Level == "Unknown"')
unknown = unknown['Gender'].count()
college = data.query('Education_Level == "College"')
college = college['Gender'].count()
post_graduate = data.query('Education_Level == "Post-Graduate"')
post_graduate = post_graduate['Gender'].count()
doctorate = data.query('Education_Level == "Doctorate"')
doctorate = doctorate['Gender'].count()
education = pd.DataFrame(data=[high_school, college, graduate, post_graduate, doctorate, uneducated, unknown], 
                         index=['High School', 'College','Graduate','Post-Graduate','Doctorate','Uneducated','Unknown'],columns=['Counts'])
education_T = education.T
education_T
# Out:
#         High School  College  Graduate  ...  Doctorate  Uneducated  Unknown
# Counts         2013     1013      3128  ...        451        1487     1519
#
# [1 rows x 7 columns]

# %%
label = ['High School', 'College','Graduate','Post-Graduate','Doctorate','Uneducated','Unknown']
counts = [high_school, college, graduate, post_graduate, doctorate, uneducated, unknown]
plt.figure(figsize = (13,5))

# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Education Level")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.2f%%", pctdistance=1.1, labeldistance=1.25, startangle=0)
plt.legend(labels=label)
plt.title("Education Level", fontsize=20);
pie.show()

# %% [markdown]
# ##Marital_Status

# %%
data.value_counts('Marital_Status')
# Out:
# Marital_Status
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# dtype: int64

# %%
married = data.query('Marital_Status == "Married"')
married = married['Gender'].count()
single = data.query('Marital_Status == "Single"')
single = single['Gender'].count()
unknown_m = data.query('Marital_Status == "Unknown"')
unknown_m = unknown_m['Gender'].count()
divorced = data.query('Marital_Status == "Divorced"')
divorced = divorced['Gender'].count()
marital = pd.DataFrame(data=[married, single, unknown_m, divorced], 
                         index=['Married', 'Single','Unknown','Divorced'],columns=['Counts'])
marital_T = marital.T
marital_T
# Out:
#         Married  Single  Unknown  Divorced
# Counts     4687    3943      749       748

# %%
label = ['Married', 'Single','Unknown','Divorced']
counts = [married, single, unknown_m, divorced]
plt.figure(figsize = (13,5))

# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Marital Status")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.2f%%", pctdistance=1.1, labeldistance=1.25, startangle=90)
plt.legend(labels=label)
plt.title("Marital Status", fontsize=20);
pie.show()

# %% [markdown]
# ##Income_Category

# %%
data.value_counts('Income_Category')
# Out:
# Income_Category
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# dtype: int64

# %%
below_40 = data.query('Income_Category == "Less than $40K"')
below_40 = below_40['Gender'].count() 
more_40 = data.query('Income_Category == "$40K - $60K"')
more_40 = more_40['Gender'].count()
more_60 = data.query('Income_Category == "$60K - $80K"')
more_60 = more_60['Gender'].count()
more_80 = data.query('Income_Category == "$80K - $120K"')
more_80 = more_80['Gender'].count()
more_120 = data.query('Income_Category == "$120K +"')
more_120 = more_120['Gender'].count()
unknown_inc = data.query('Income_Category == "Unknown"')
unknown_inc = unknown_inc['Gender'].count()
income = pd.DataFrame(data=[below_40, more_40, more_60, more_80, more_120, unknown_inc], 
                         index=['Less than $40K', '$40K - $60K','$60K - $80K','$80K - $120K', '$120K +', 'Unknown'],columns=['Counts'])
income_T = income.T
income_T
# Out:
#         Less than $40K  $40K - $60K  ...  $120K +  Unknown
# Counts            3561         1790  ...      727     1112
#
# [1 rows x 6 columns]

# %%
label = ['Less than $40K', '$40K - $60K','$60K - $80K','$80K - $120K', '$120K +', 'Unknown']
counts = [below_40, more_40, more_60, more_80, more_120, unknown_inc]
plt.figure(figsize = (13,5))

# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Income Category")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.2f%%", pctdistance=1.1, labeldistance=1.25, startangle=90)
plt.legend(labels=label)
plt.title("Income Category", fontsize=20);
pie.show()

# %% [markdown]
# ##Card_Category

# %%
data.value_counts('Card_Category')
# Out:
# Card_Category
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# dtype: int64

# %%
blue = data.query('Card_Category == "Blue"')
blue = blue['Gender'].count()
silver = data.query('Card_Category == "Silver"')
silver = silver['Gender'].count()
gold = data.query('Card_Category == "Gold"')
gold = gold['Gender'].count()
platinum = data.query('Card_Category == "Platinum"')
platinum = platinum['Gender'].count()
card = pd.DataFrame(data=[blue, silver, gold, platinum], 
                         index=['Blue', 'Silver','Gold','Platinum'],columns=['Counts'])
card_T = card.T
card_T
# Out:
#         Blue  Silver  Gold  Platinum
# Counts  9436     555   116        20

# %%
label = ['Blue', 'Silver','Gold','Platinum']
counts = [blue, silver, gold, platinum]
plt.figure(figsize = (13,5))

# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Card Category")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.2f%%", explode=[0.15]*4, pctdistance=1.105, labeldistance=1.25, startangle=45)
plt.legend(labels=label)
plt.title("Card Category", fontsize=20);
pie.show()

# %% [markdown]
# ##Months_on_book

# %%
data.value_counts('Months_on_book')
# Out:
# Months_on_book
# 36    2463
# 37     358
# 34     353
# 38     347
# 39     341
# 40     333
# 31     318
# 35     317
# 33     305
# 30     300
# 41     297
# 32     289
# 28     275
# 43     273
# 42     271
# 29     241
# 44     230
# 45     227
# 27     206
# 46     197
# 26     186
# 47     171
# 25     165
# 48     162
# 24     160
# 49     141
# 23     116
# 22     105
# 56     103
# 50      96
# 21      83
# 51      80
# 53      78
# 20      74
# 13      70
# 19      63
# 52      62
# 18      58
# 54      53
# 55      42
# 17      39
# 15      34
# 16      29
# 14      16
# dtype: int64

# %%
month_12 = data.query("Months_on_book >= 12 & Months_on_book < 18")
month_12 = month_12['Gender'].count()
month_18 = data.query("Months_on_book >= 18 & Months_on_book < 24")
month_18 = month_18['Gender'].count()
month_24 = data.query("Months_on_book >= 24 & Months_on_book < 30")
month_24 = month_24['Gender'].count()
month_30 = data.query("Months_on_book >= 30 & Months_on_book < 36")
month_30 = month_30['Gender'].count()
month_36 = data.query("Months_on_book >= 36 & Months_on_book < 42")
month_36 = month_36['Gender'].count()
month_42 = data.query("Months_on_book >= 42 & Months_on_book < 48")
month_42 = month_42['Gender'].count()
month_48 = data.query("Months_on_book >= 48 & Months_on_book < 54")
month_48 = month_48['Gender'].count()
month_54 = data.query("Months_on_book >= 54 & Months_on_book < 60")
month_54 = month_54['Gender'].count()
months_book = pd.DataFrame(data=[month_12,month_18,month_24,month_30,month_36,month_42,month_48,month_54], 
                           index=['12-17','18-23','24-29','30-35','36-41','42-47','48-53','54-60'],columns=['Counts'])
months_book_T = months_book.T
months_book_T
# Out:
#         12-17  18-23  24-29  30-35  36-41  42-47  48-53  54-60
# Counts    188    499   1233   1882   4139   1369    619    198

# %%
label = ['12-17','18-23','24-29','30-35','36-41','42-47','48-53','54-60']
counts = [month_12,month_18,month_24,month_30,month_36,month_42,month_48,month_54]
plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Months on book")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.2f%%", pctdistance=1.1, labeldistance=1.25, startangle=45)
plt.legend(labels=label)
plt.title("Months on book", fontsize=20);
pie.show()

# %% [markdown]
# ##Total_Relationship_Count

# %%
data.value_counts('Total_Relationship_Count')
# Out:
# Total_Relationship_Count
# 3    2305
# 4    1912
# 5    1891
# 6    1866
# 2    1243
# 1     910
# dtype: int64

# %%
relation_1 = data.query("Total_Relationship_Count == 1")
relation_1 = relation_1['Gender'].count()
relation_2 = data.query("Total_Relationship_Count == 2")
relation_2 = relation_2['Gender'].count()
relation_3 = data.query("Total_Relationship_Count == 3")
relation_3 = relation_3['Gender'].count()
relation_4 = data.query("Total_Relationship_Count == 4")
relation_4 = relation_4['Gender'].count()
relation_5 = data.query("Total_Relationship_Count == 5")
relation_5 = relation_5['Gender'].count()
relation_6 = data.query("Total_Relationship_Count == 6")
relation_6 = relation_6['Gender'].count()

relationship = pd.DataFrame(data=[relation_1,relation_2,relation_3,relation_4,relation_5,relation_6], 
                           index=['1','2','3','4','5','6'],columns=['Counts'])
relationship_T = relationship.T
relationship_T
# Out:
#           1     2     3     4     5     6
# Counts  910  1243  2305  1912  1891  1866

# %%
label = ['1','2','3','4','5','6']
counts = [relation_1,relation_2,relation_3,relation_4,relation_5,relation_6]
plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Total Relationship Count")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[10,10])
plt.pie(x=counts, autopct="%.2f%%", pctdistance=1.1, labeldistance=1.25, startangle=90)
plt.legend(labels=label)
plt.title("Total Relationship Count", fontsize=20);
pie.show()

# %% [markdown]
# ##Months_Inactive_12_mon

# %%
data.value_counts('Months_Inactive_12_mon')
# Out:
# Months_Inactive_12_mon
# 3    3846
# 2    3282
# 1    2233
# 4     435
# 5     178
# 6     124
# 0      29
# dtype: int64

# %%
inactive_0 = data.query("Months_Inactive_12_mon == 1")
inactive_0 = inactive_0['Gender'].count()
inactive_1 = data.query("Months_Inactive_12_mon == 2")
inactive_1 = inactive_1['Gender'].count()
inactive_2 = data.query("Months_Inactive_12_mon == 3")
inactive_2 = inactive_2['Gender'].count()
inactive_3 = data.query("Months_Inactive_12_mon == 4")
inactive_3 = inactive_3['Gender'].count()
inactive_4 = data.query("Months_Inactive_12_mon == 5")
inactive_4 = inactive_4['Gender'].count()
inactive_5 = data.query("Months_Inactive_12_mon == 6")
inactive_5 = inactive_5['Gender'].count()
inactive_6 = data.query("Months_Inactive_12_mon == 6")
inactive_6 = inactive_6['Gender'].count()

inactive = pd.DataFrame(data=[inactive_0,inactive_1,inactive_2,inactive_3,inactive_4,inactive_5,inactive_6], 
                           index=['0','1','2','3','4','5','6'],columns=['Counts'])
inactive_T = inactive.T
inactive_T
# Out:
#            0     1     2    3    4    5    6
# Counts  2233  3282  3846  435  178  124  124

# %%
label = ['0','1','2','3','4','5','6']
counts = [inactive_0,inactive_1,inactive_2,inactive_3,inactive_4,inactive_5,inactive_6]
plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Months Inactive Last 12 Months")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[12,12])
plt.pie(x=counts, autopct="%.1f%%", pctdistance=1.15, labeldistance=1.25, startangle=0)
plt.legend(labels=label)
plt.title("Months Inactive Last 12 Months", fontsize=20);
pie.show()

# %%
#months Inactive Last 12 Month

# %% [markdown]
# ##Contacts_Count_12_mon

# %%
data.value_counts('Contacts_Count_12_mon')
# Out:
# Contacts_Count_12_mon
# 3    3380
# 2    3227
# 1    1499
# 4    1392
# 0     399
# 5     176
# 6      54
# dtype: int64

# %%
contact_0 = data.query("Contacts_Count_12_mon == 1")
contact_0 = contact_0['Gender'].count()
contact_1 = data.query("Contacts_Count_12_mon == 2")
contact_1 = contact_1['Gender'].count()
contact_2 = data.query("Contacts_Count_12_mon == 3")
contact_2 = contact_2['Gender'].count()
contact_3 = data.query("Contacts_Count_12_mon == 4")
contact_3 = contact_3['Gender'].count()
contact_4 = data.query("Contacts_Count_12_mon == 5")
contact_4 = contact_4['Gender'].count()
contact_5 = data.query("Contacts_Count_12_mon == 6")
contact_5 = contact_5['Gender'].count()
contact_6 = data.query("Contacts_Count_12_mon == 6")
contact_6 = contact_6['Gender'].count()

contact = pd.DataFrame(data=[contact_0,contact_1,contact_2,contact_3,contact_4,contact_5,contact_6], 
                           index=['0','1','2','3','4','5','6'],columns=['Counts'])
contact_T = contact.T
contact_T
# Out:
#            0     1     2     3    4   5   6
# Counts  1499  3227  3380  1392  176  54  54

# %%
label = ['0','1','2','3','4','5','6']
counts = [contact_0,contact_1,contact_2,contact_3,contact_4,contact_5,contact_6]
plt.figure(figsize = (10,5))
# making the bar chart on the data
plt.bar(label, counts)
  
# calling the function to add value labels
addlabels(label, counts)

# giving title to the plot
plt.title("Contacts Count Last 12 Months")
plt.show()

# %%
pie, ax = plt.subplots(figsize=[12,12])
plt.pie(x=counts, autopct="%.1f%%", pctdistance=1.105, labeldistance=1.25, startangle=0)
plt.legend(labels=label)
plt.title("Contacts Count Last 12 Months", fontsize=20);
pie.show()

# %% [markdown]
# ##Credit_Limit

# %%
data.value_counts('Credit_Limit')
# Out:
# Credit_Limit
# 34516.0    508
# 1438.3     507
# 15987.0     18
# 9959.0      18
# 23981.0     12
#           ...
# 10130.0      1
# 10133.0      1
# 10136.0      1
# 10144.0      1
# 6511.0       1
# Length: 6205, dtype: int64

# %%
plt.figure(figsize = (15,10))
plt.title("Credit Limit", fontsize=20);
data.Credit_Limit.hist(bins=10)

# %% [markdown]
# ##Total_Revolving_Bal

# %%
data.value_counts('Total_Revolving_Bal')
# Out:
# Total_Revolving_Bal
# 0       2470
# 2517     508
# 1965      12
# 1480      12
# 1664      11
#         ...
# 1712       1
# 1756       1
# 1757       1
# 1768       1
# 1447       1
# Length: 1974, dtype: int64

# %%
plt.figure(figsize = (15,10))
plt.title("Total Revolving Balance", fontsize=20);
data.Total_Revolving_Bal.hist(bins=10)

# %% [markdown]
# ##Avg_Open_To_Buy

# %%
data.value_counts('Avg_Open_To_Buy')
# Out:
# Avg_Open_To_Buy
# 1438.3     324
# 34516.0     98
# 31999.0     26
# 787.0        8
# 713.0        7
#           ...
# 9637.0       1
# 9641.0       1
# 9661.0       1
# 9663.0       1
# 3.0          1
# Length: 6813, dtype: int64

# %%
plt.figure(figsize = (15,10))
plt.title("Average Open To Buy", fontsize=20);
data.Avg_Open_To_Buy.hist(bins=10)

# %% [markdown]
# ##Total_Amt_Chng_Q4_Q1

# %%
data.value_counts('Total_Amt_Chng_Q4_Q1')
# Out:
# Total_Amt_Chng_Q4_Q1
# 0.791    36
# 0.712    34
# 0.743    34
# 0.735    33
# 0.718    33
#          ..
# 1.458     1
# 1.456     1
# 1.449     1
# 1.441     1
# 3.397     1
# Length: 1158, dtype: int64

# %%
plt.figure(figsize = (15,10))
plt.title("Total Amount Change Q4-Q1", fontsize=20);
data.Total_Amt_Chng_Q4_Q1.hist(bins=10)

# %% [markdown]
# ##Total_Trans_Amt

# %%
data.value_counts('Total_Trans_Amt')
# Out:
# Total_Trans_Amt
# 4253    11
# 4509    11
# 2229    10
# 4518    10
# 4498     9
#         ..
# 5425     1
# 5421     1
# 5418     1
# 5413     1
# 510      1
# Length: 5033, dtype: int64

# %%
plt.figure(figsize = (15,10))
plt.title("Total Transaction Amounts", fontsize=20);
data.Total_Trans_Amt.hist(bins=10)

# %% [markdown]
# ##Total_Trans_Ct

# %%
data.value_counts('Total_Trans_Ct')
# Out:
# Total_Trans_Ct
# 81     208
# 75     203
# 71     203
# 69     202
# 82     202
#       ...
# 11       2
# 138      1
# 132      1
# 134      1
# 139      1
# Length: 126, dtype: int64

# %%
data['Total_Trans_Ct'].describe()
# Out:
# count    10127.000000
# mean        64.858695
# std         23.472570
# min         10.000000
# 25%         45.000000
# 50%         67.000000
# 75%         81.000000
# max        139.000000
# Name: Total_Trans_Ct, dtype: float64

# %%
plt.figure(figsize = (15,10))
plt.title("Total Transaction Counts", fontsize=20);
data.Total_Trans_Ct.hist(bins=10)

# %% [markdown]
# ##Total_Ct_Chng_Q4_Q1

# %%
data.value_counts('Total_Ct_Chng_Q4_Q1')
# Out:
# Total_Ct_Chng_Q4_Q1
# 0.667    171
# 1.000    166
# 0.500    161
# 0.750    156
# 0.600    113
#         ...
# 1.476      1
# 1.478      1
# 0.434      1
# 1.480      1
# 3.714      1
# Length: 830, dtype: int64

# %%
plt.figure(figsize = (10,5))
plt.title("Total Count Change Q4-Q1", fontsize=20);
data.Total_Ct_Chng_Q4_Q1.hist(bins=10)

# %% [markdown]
# ##Avg_Utilization_Ratio

# %%
data.value_counts('Avg_Utilization_Ratio')
# Out:
# Avg_Utilization_Ratio
# 0.000    2470
# 0.073      44
# 0.057      33
# 0.048      32
# 0.060      30
#          ...
# 0.921       1
# 0.920       1
# 0.918       1
# 0.916       1
# 0.999       1
# Length: 964, dtype: int64

# %%
plt.figure(figsize = (10,5))
plt.title("Average Utilization Ratio", fontsize=20);
data.Avg_Utilization_Ratio.hist(bins=10)
